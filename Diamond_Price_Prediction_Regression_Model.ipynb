# %% [markdown]
# # **Diamond Price Prediction**

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\ayush\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\ayush\anaconda3\lib\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\ayush\anaconda3\lib\site-packages (from missingno) (3.9.2)
# Requirement already satisfied: scipy in c:\users\ayush\anaconda3\lib\site-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in c:\users\ayush\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayush\anaconda3\lib\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayush\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayush\anaconda3\lib\site-packages (from matplotlib->missingno) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayush\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ayush\anaconda3\lib\site-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ayush\anaconda3\lib\site-packages (from matplotlib->missingno) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ayush\anaconda3\lib\site-packages (from matplotlib->missingno) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayush\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ayush\anaconda3\lib\site-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayush\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ayush\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ayush\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %% [markdown]
# # Reading the Data

# %%
df = pd.read_csv(r"C:\Users\ayush\Downloads\diamonds.csv")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# # Understanding the Data

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.size
# Out:
# 539400

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
df.corr(numeric_only=True)
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
df.nunique()
# Out:
# carat        273
# cut            5
# color          7
# clarity        8
# depth        184
# table        127
# price      11602
# x            554
# y            552
# z            375
# dtype: int64

# %%
df.isnull().any()
# Out:
# carat      False
# cut        False
# color      False
# clarity    False
# depth      False
# table      False
# price      False
# x          False
# y          False
# z          False
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder
labelencoding = LabelEncoder()
categories=['cut', 'color',	'clarity']
df[categories]=df[categories].apply(lambda x:labelencoding.fit_transform(x))
df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72    2      0        2   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72    1      0        2   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70    4      0        2   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    3      4        3   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    2      0        3   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# # Visualiztion

# %%
import missingno as no
no.bar(df, color='lightblue')
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull(), yticklabels='False', cmap='Greens')
# Out:
# <Axes: >

# %%
df1 = df['cut'].value_counts()
plt.pie(df1.values, labels=df1.index, autopct='%0.2f%%')
plt.title('Pecentage of Cut', fontsize=15)
plt.show()

# %%
sns.displot(df['price'], color='red')

# %%
plt.hist(df['carat'],bins = 30, color='g')
plt.xlabel('carat')
plt.ylabel('price')
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x=df.color, y=df.carat, hue=df.color, palette='rainbow', legend=False)
# Out:
# <Axes: xlabel='color', ylabel='carat'>

# %%
plt.figure(figsize=(10,5))
sns.stripplot(x=df.clarity, y=df.carat,hue=df.color, palette='magma_r',legend=False)
plt.show()

# %%
sns.boxplot(x='clarity',y='price',data=df)
plt.show()

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df.corr(), yticklabels='auto', annot=True)
plt.show()

# %% [markdown]
# # Splitting the Data into Dependent and Independent Variables

# %%
x = df.drop(['cut', 'color',	'clarity', 'price'], axis=1)
y = df["price"]

# %%
x.shape
# Out:
# (53940, 6)

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
print(model.feature_importances_)
# Out:
# [0.46156809 0.02491514 0.01791659 0.33813944 0.09126222 0.06619853]

# %%
feat_imp = pd.Series(model.feature_importances_, index=x.columns)

# %%
feat_imp.nlargest(5).plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# # Training and Testing the Data

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=23)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# ## Prediction

# %%
ypred_train = lr.predict(xtrain)
ypred_test = lr.predict(xtest)

# %% [markdown]
# ## Accuracy

# %%
from sklearn import metrics
print("Accuracy of training data:", metrics.r2_score(ytrain, ypred_train)*100)
ac1 = metrics.r2_score(ytest, ypred_test)*100
print("Accuracy of testing data:", ac1)
# Out:
# Accuracy of training data: 86.03402181161945
# Accuracy of testing data: 85.5896797526322

# %% [markdown]
# ## Error

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest, ypred_test)
print("Mean Square Error:", mse)
# Out:
# Mean Square Error: 2264310.33040005

# %% [markdown]
# # KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=10)
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %% [markdown]
# ## Prediction

# %%
ypred_train = knn.predict(xtrain)
ypred_test = knn.predict(xtest)

# %% [markdown]
# ## Accuracy

# %%
from sklearn import metrics
print("Accuracy of training data:", metrics.r2_score(ytrain, ypred_train)*100)
ac2 = metrics.r2_score(ytest, ypred_test)*100
print("Accuracy of testing data:", ac2)
# Out:
# Accuracy of training data: 89.77339732569898
# Accuracy of testing data: 87.22245496706861

# %% [markdown]
# ## Error

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest, ypred_test)
print("Mean Square Error:", mse)
# Out:
# Mean Square Error: 2007750.4676208133

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(ccp_alpha=0.1, max_depth=5)
dt.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.1, max_depth=5)

# %% [markdown]
# ## Prediction

# %%
ypred_train = dt.predict(xtrain)
ypred_test = dt.predict(xtest)

# %% [markdown]
# ## Accuracy

# %%
from sklearn import metrics
print("Accuracy of training data:", metrics.r2_score(ytrain, ypred_train)*100)
ac3 = metrics.r2_score(ytest, ypred_test)*100
print("Accuracy of testing data:", ac3)
# Out:
# Accuracy of training data: 88.16546002805383
# Accuracy of testing data: 87.49126803815874

# %% [markdown]
# ## Error

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest, ypred_test)
print("Mean Square Error:", mse)
# Out:
# Mean Square Error: 1965511.5580499365

# %% [markdown]
# # Comparing Accuracy

# %%
accuracy =  {ac1: 'Logistic Regression', ac2: 'KNN', ac3:'Decision Tree'}

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(14, 10))
model_accuracies = list(accuracy.values())
model_names = list(accuracy.keys())
sns.barplot(x=model_accuracies, y=model_names,  palette='gist_rainbow')
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_14988\2048944590.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=model_accuracies, y=model_names,  palette='gist_rainbow')
# <Axes: >

# %% [markdown]
# As accuracy of **Decision Tree Regressor** algorithm is more ie. **87.49%**
#
# Hence we will save the model.

# %% [markdown]
# # Saving the Model

# %%
import pickle 
pickle.dump(dt, open('model.pkl', 'wb'))
